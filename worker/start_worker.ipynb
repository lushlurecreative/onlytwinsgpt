# %% [markdown]
# # Start ONLYTWINS Worker
#
# 1. **Set env vars in RunPod:** Pod → **Edit Template** → **Environment Variables**. Add: `WORKER_SECRET`, `APP_URL`, `NEXT_PUBLIC_SUPABASE_URL`, `SUPABASE_SERVICE_ROLE_KEY`, `HF_TOKEN` (for FLUX).
#
# 2. **Ensure the repo is at `/workspace/onlytwinsgpt`** (clone there if needed). If your repo is elsewhere, edit the path in the code cell below.
#
# 3. **Run the code cell below:** Run → Run All, or click the play button on the cell. Worker output will appear in that cell. No web terminal needed.

# %%
# %cd /workspace/onlytwinsgpt/worker
# !python -u main.py
